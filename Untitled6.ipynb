# %% [markdown]
# <a href="https://colab.research.google.com/github/Manuel781041/movies-dataset/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Load Data and Display Column Names

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('/content/salida_adsb.csv')

print("DataFrame loaded successfully.")
# Out:
# DataFrame loaded successfully.

# %%
# Display all column names
print("Column names:")
for col in df.columns:
    print(col)
# Out:
# Column names:
# frame
# time_epoch
# src_ip
# lat
# lon
# altitude_ft
# flight_level
# aircraft_id
# aircraft_address
# adsb_version

# %% [markdown]
# ### Vista Previa de Datos de Aeronaves (Primeras 50 Filas)

# %%
selected_columns_df = df[['aircraft_address', 'aircraft_id', 'flight_level', 'adsb_version']]
display(selected_columns_df.head(50))
# Out:
#    aircraft_address aircraft_id  flight_level adsb_version
# 0               NaN         NaN           NaN          NaN
# 1          0xad4ebc      TAI428        287.75      DO-260B
# 2          0xaaa6dd      AAL908        380.00      DO-260B
# 3          0xaac136      UAL819        370.00      DO-260B
# 4          0x0c4354     DWI3761        370.00      DO-260B
# 5          0xaa6914      AAL945        310.00      DO-260B
# 6          0xc027da     CJT1507        350.00      DO-260B
# 7          0xa89234      UAL855        300.00      DO-260B
# 8          0x0d0d6d     VOI3918        370.00      DO-260B
# 9          0x0c20d6      CMP338        320.00      DO-260B
# 10         0xaa57e6      AVA240        360.00      DO-260B
# 11         0x0d0d6d     VOI3918        370.00      DO-260B
# 12         0x0c4355     DWI6771        350.00      DO-260B
# 13         0x0c4355     DWI6771        350.00      DO-260B
# 14         0xaa57e6      AVA240        360.00      DO-260B
# ...

# %% [markdown]
# ### Revisión de la columna `flight_level`

# %%
print(f"Tipo de datos de 'flight_level': {df['flight_level'].dtype}")
# Out:
# Tipo de datos de 'flight_level': float64

# %%
print("Estadísticas descriptivas para 'flight_level':")
display(df['flight_level'].describe())
# Out:
# Estadísticas descriptivas para 'flight_level':
# count    65099.000000
# mean       349.693187
# std         36.582007
# min         74.500000
# 25%        330.500000
# 50%        350.000000
# 75%        370.000000
# max        450.250000
# Name: flight_level, dtype: float64

# %%
print("Primeros 20 valores únicos de 'flight_level':")
display(df['flight_level'].value_counts().head(20))
# Out:
# Primeros 20 valores únicos de 'flight_level':
# flight_level
# 340.00    8429
# 320.00    8357
# 360.00    7722
# 370.00    7665
# 350.00    5764
# 330.50    3623
# 390.00    3336
# 380.00    2936
# 450.00    1951
# 350.25    1419
# 360.25    1409
# 359.75    1266
# 389.75    1040
# 370.25     672
# 330.00     585
# 369.75     580
# 339.75     478
# 300.00     362
# 300.25     310
# 360.50     297
# Name: count, dtype: int64
